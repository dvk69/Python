# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk69/Python/blob/main/LetSintroduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
name = "Vineeth"
age = "26"
print("My name is",name)
print("My age is", age)
# Out:
# My name is Vineeth
# My age is 26

# %%
user = input("What's your name?")
print("Welcome",user,"!","Thank you for visiting my GitHub")
# Out:
# What's your name?user
# Welcome user ! Thank you for visiting my GitHub

# %%
your_age= int(input("What's your age?"))
if your_age>=21:
  print("You are an adult")
elif your_age<=13:
    print("you are a kid")
else:
      print("you are a teenager")
# Out:
# What's your age?26
# You are an adult
