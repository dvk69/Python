# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk69/Python/blob/main/NumberGuessingGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
random_number = random.randint(1,10)
attempts = 3

print("I am thinking of a number between 1 and 10. Can you guess what it is?")
while attempts > 0:
    guess = int(input("Enter your guess: "))
    if guess == random_number:
        print("Congratulations! You guessed the number!")
        break
    elif guess < random_number:
        print("Too low! Try again.")
    else:
        print("Too high! Try again.")
    attempts -= 1
if attempts == 0:
    print("Sorry, you ran out of attempts. The number was", random_number)
# Out:
# I am thinking of a number between 1 and 10. Can you guess what it is?
# Enter your guess: 7
# Too low! Try again.
# Enter your guess: 9
# Too low! Try again.
# Enter your guess: 10
# Congratulations! You guessed the number!
