# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk69/Python/blob/main/SimpleCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=float(input("What is the First number? "))
b=float(input("What is the Second number? "))


print("\nOptions are: \n")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Modulus")
print("6. Exponent")
print("7. Floor_Division")

choice = int(input("\nEnter your choice (1-7): "))

def switch(choice):
  if choice == 1:
    print(f"\nAddition of {a} and {b} is : {a + b}")
  elif choice == 2:
    print(f"\nSubtraction of {a} and {b} is : {a - b}")
  elif choice == 3:
    print(f"\nMultiplication of {a} and {b} is : {a * b}")
  elif choice == 4:
    if b == 0:
      print("\nCannot divide by zero")
    else:
      print(f"\nDivision of {a} and {b} is : {a / b}")
  elif choice == 5:
    if b == 0:
      print("\nCannot divide by zero")
    else:
      print(f"\nModulus of {a} and {b} is : {a % b}")
  elif choice == 6:
    print(f"\nExponent of {a} and {b} is : {a ** b}")
  elif choice == 7:
    print(f"\nFloor_Division of {a} and {b} is : {a // b}")
  else:
    print("Invalid choice")

switch(choice)
# Out:
# What is the first number? 21
# What is the second number? 7
#
# Options are:
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponent
# 7. Floor_Division
#
# Enter your choice (1-7): 4
#
# Division of 21.0 and 7.0 is : 3.0
